# %%
import pandas as pd
import numpy as np
import requests
import json
import os

# %%
url = "https://statsapi.web.nhl.com/api/v1/teams"

# %%
response = requests.get(url + "?expand=team.stats")
print(response.content)
#print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# b'{\n  "copyright" : "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \xc2\xa9 NHL 2020. All Rights Reserved.",\n  "teams" : [ {\n    "id" : 1,\n    "name" : "New Jersey Devils",\n    "link" : "/api/v1/teams/1",\n    "venue" : {\n      "name" : "Prudential Center",\n      "link" : "/api/v1/venues/null",\n      "city" : "Newark",\n      "timeZone" : {\n        "id" : "America/New_York",\n        "offset" : -4,\n        "tz" : "EDT"\n      }\n    },\n    "abbreviation" : "NJD",\n    "teamName" : "Devils",\n    "locationName" : "New Jersey",\n    "firstYearOfPlay" : "1982",\n    "division" : {\n      "id" : 18,\n      "name" : "Metropolitan",\n      "nameShort" : "Metro",\n      "link" : "/api/v1/divisions/18",\n      "abbreviation" : "M"\n    },\n    "conference" : {\n      "id" : 6,\n      "name" : "Eastern",\n      "link" : "/api/v1/conferences/6"\n    },\n    "franchise" : {\n      "fra
# ...

# %%
response = requests.get(url + "?expand=team.stats").json()
print(response)
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2020. All Rights Reserved.', 'teams': [{'id': 1, 'name': 'New Jersey Devils', 'link': '/api/v1/teams/1', 'venue': {'name': 'Prudential Center', 'link': '/api/v1/venues/null', 'city': 'Newark', 'timeZone': {'id': 'America/New_York', 'offset': -4, 'tz': 'EDT'}}, 'abbreviation': 'NJD', 'teamName': 'Devils', 'locationName': 'New Jersey', 'firstYearOfPlay': '1982', 'division': {'id': 18, 'name': 'Metropolitan', 'nameShort': 'Metro', 'link': '/api/v1/divisions/18', 'abbreviation': 'M'}, 'conference': {'id': 6, 'name': 'Eastern', 'link': '/api/v1/conferences/6'}, 'franchise': {'franchiseId': 23, 'teamName': 'Devils', 'link': '/api/v1/franchises/23'}, 'teamStats': [{'type': {'displayName': 'statsSingleSeason', 'gameType': {'id': 'R', 'description': 'Regular season', 'postseason': False}}, 'splits': [{'stat': {'gamesPlayed': 69,
# ...

# %%
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "NJD",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1982",
#             "franchise": {
#                 "franchiseId": 23,
#                 "link": "/api/v1/franchises/23",
#                 "teamName": "Devils"
#             },
#             "franchiseId": 23,
#             "id": 1,
# ...

# %%
# response["name"] = ""
# response["faceOffsWon"] = ""
# response["goalsPerGame"] = ""

# %%
with open('outputfile.json', 'wb') as outf:
    outf.write(response.content)

# %%
df = pd.read_json('outputfile.json')
df
# print(df)
# Out:
#                                             copyright  \
# 0   NHL and the NHL Shield are registered trademar...
# 1   NHL and the NHL Shield are registered trademar...
# 2   NHL and the NHL Shield are registered trademar...
# 3   NHL and the NHL Shield are registered trademar...
# 4   NHL and the NHL Shield are registered trademar...
# 5   NHL and the NHL Shield are registered trademar...
# 6   NHL and the NHL Shield are registered trademar...
# 7   NHL and the NHL Shield are registered trademar...
# 8   NHL and the NHL Shield are registered trademar...
# 9   NHL and the NHL Shield are registered trademar...
# 10  NHL and the NHL Shield are registered trademar...
# 11  NHL and the NHL Shield are registered trademar...
# 12  NHL and the NHL Shield are registered trademar...
# 13  NHL and the NHL Shield are registered trademar...
# 14  NHL and the NHL Shield are registered trademar...
# 15  NHL and the NHL Shield are registered trademar...
# ...

# %%
# response["name"] = ""
# response["faceOffsWon"] = ""
# response["goalsPerGame"] = ""
# response

# %%
print(requests.get(url))
# Out:
# <Response [200]>

# %%
print(requests.get(url).json())
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2020. All Rights Reserved.', 'teams': [{'id': 1, 'name': 'New Jersey Devils', 'link': '/api/v1/teams/1', 'venue': {'name': 'Prudential Center', 'link': '/api/v1/venues/null', 'city': 'Newark', 'timeZone': {'id': 'America/New_York', 'offset': -4, 'tz': 'EDT'}}, 'abbreviation': 'NJD', 'teamName': 'Devils', 'locationName': 'New Jersey', 'firstYearOfPlay': '1982', 'division': {'id': 18, 'name': 'Metropolitan', 'nameShort': 'Metro', 'link': '/api/v1/divisions/18', 'abbreviation': 'M'}, 'conference': {'id': 6, 'name': 'Eastern', 'link': '/api/v1/conferences/6'}, 'franchise': {'franchiseId': 23, 'teamName': 'Devils', 'link': '/api/v1/franchises/23'}, 'shortName': 'New Jersey', 'officialSiteUrl': 'http://www.newjerseydevils.com/', 'franchiseId': 23, 'active': True}, {'id': 2, 'name': 'New York Islanders', 'link': '/api/v1/teams
# ...

# %%
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "NJD",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1982",
#             "franchise": {
#                 "franchiseId": 23,
#                 "link": "/api/v1/franchises/23",
#                 "teamName": "Devils"
#             },
#             "franchiseId": 23,
#             "id": 1,
# ...

# %%
response = requests.get(url + "/1").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "NJD",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1982",
#             "franchise": {
#                 "franchiseId": 23,
#                 "link": "/api/v1/franchises/23",
#                 "teamName": "Devils"
#             },
#             "franchiseId": 23,
#             "id": 1,
# ...

# %%
response = requests.get(url + "?expand=team.stats").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "NJD",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1982",
#             "franchise": {
#                 "franchiseId": 23,
#                 "link": "/api/v1/franchises/23",
#                 "teamName": "Devils"
#             },
#             "franchiseId": 23,
#             "id": 1,
# ...

# %%
response = requests.get(url + "/2").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "NYI",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1972",
#             "franchise": {
#                 "franchiseId": 22,
#                 "link": "/api/v1/franchises/22",
#                 "teamName": "Islanders"
#             },
#             "franchiseId": 22,
#             "id": 2,
# ...

# %%
response = requests.get(url + "?expand=team.stats").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "NJD",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1982",
#             "franchise": {
#                 "franchiseId": 23,
#                 "link": "/api/v1/franchises/23",
#                 "teamName": "Devils"
#             },
#             "franchiseId": 23,
#             "id": 1,
# ...

# %%
response = requests.get(url + "/3").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "NYR",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1926",
#             "franchise": {
#                 "franchiseId": 10,
#                 "link": "/api/v1/franchises/10",
#                 "teamName": "Rangers"
#             },
#             "franchiseId": 10,
#             "id": 3,
# ...

# %%
response = requests.get(url + "?expand=team.stats").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "NJD",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1982",
#             "franchise": {
#                 "franchiseId": 23,
#                 "link": "/api/v1/franchises/23",
#                 "teamName": "Devils"
#             },
#             "franchiseId": 23,
#             "id": 1,
# ...

# %%
response = requests.get(url + "/4").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "PHI",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1967",
#             "franchise": {
#                 "franchiseId": 16,
#                 "link": "/api/v1/franchises/16",
#                 "teamName": "Flyers"
#             },
#             "franchiseId": 16,
#             "id": 4,
# ...

# %%
response = requests.get(url + "/5").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "PIT",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1967",
#             "franchise": {
#                 "franchiseId": 17,
#                 "link": "/api/v1/franchises/17",
#                 "teamName": "Penguins"
#             },
#             "franchiseId": 17,
#             "id": 5,
# ...

# %%
response = requests.get(url + "/6").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "BOS",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "A",
#                 "id": 17,
#                 "link": "/api/v1/divisions/17",
#                 "name": "Atlantic",
#                 "nameShort": "ATL"
#             },
#             "firstYearOfPlay": "1924",
#             "franchise": {
#                 "franchiseId": 6,
#                 "link": "/api/v1/franchises/6",
#                 "teamName": "Bruins"
#             },
#             "franchiseId": 6,
#             "id": 6,
# ...

# %%
response = requests.get(url + "/7").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "BUF",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "A",
#                 "id": 17,
#                 "link": "/api/v1/divisions/17",
#                 "name": "Atlantic",
#                 "nameShort": "ATL"
#             },
#             "firstYearOfPlay": "1970",
#             "franchise": {
#                 "franchiseId": 19,
#                 "link": "/api/v1/franchises/19",
#                 "teamName": "Sabres"
#             },
#             "franchiseId": 19,
#             "id": 7,
# ...

# %%
response = requests.get(url + "/8").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "MTL",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "A",
#                 "id": 17,
#                 "link": "/api/v1/divisions/17",
#                 "name": "Atlantic",
#                 "nameShort": "ATL"
#             },
#             "firstYearOfPlay": "1909",
#             "franchise": {
#                 "franchiseId": 1,
#                 "link": "/api/v1/franchises/1",
#                 "teamName": "Canadiens"
#             },
#             "franchiseId": 1,
#             "id": 8,
# ...

# %%
response = requests.get(url + "/9").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "OTT",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "A",
#                 "id": 17,
#                 "link": "/api/v1/divisions/17",
#                 "name": "Atlantic",
#                 "nameShort": "ATL"
#             },
#             "firstYearOfPlay": "1990",
#             "franchise": {
#                 "franchiseId": 30,
#                 "link": "/api/v1/franchises/30",
#                 "teamName": "Senators"
#             },
#             "franchiseId": 30,
#             "id": 9,
# ...

# %%
response = requests.get(url + "/10").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "TOR",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "A",
#                 "id": 17,
#                 "link": "/api/v1/divisions/17",
#                 "name": "Atlantic",
#                 "nameShort": "ATL"
#             },
#             "firstYearOfPlay": "1917",
#             "franchise": {
#                 "franchiseId": 5,
#                 "link": "/api/v1/franchises/5",
#                 "teamName": "Maple Leafs"
#             },
#             "franchiseId": 5,
#             "id": 10,
# ...

# %%
response = requests.get(url + "/11").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "ATL",
#             "active": false,
#             "conference": {
#                 "link": "/api/v1/conferences/null"
#             },
#             "division": {
#                 "link": "/api/v1/divisions/null"
#             },
#             "firstYearOfPlay": "1997",
#             "franchise": {
#                 "franchiseId": 35,
#                 "link": "/api/v1/franchises/35",
#                 "teamName": "Jets"
#             },
#             "franchiseId": 35,
#             "id": 11,
#             "link": "/api/v1/teams/11",
#             "locationName": "Atlanta",
#             "name": "Atlanta Thrashers",
#             "officialSiteUrl": "http://www.atlantathrashers.com/",
# ...

# %%
response = requests.get(url + "/12").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "CAR",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1979",
#             "franchise": {
#                 "franchiseId": 26,
#                 "link": "/api/v1/franchises/26",
#                 "teamName": "Hurricanes"
#             },
#             "franchiseId": 26,
#             "id": 12,
# ...

# %%
response = requests.get(url + "/13").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "FLA",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "A",
#                 "id": 17,
#                 "link": "/api/v1/divisions/17",
#                 "name": "Atlantic",
#                 "nameShort": "ATL"
#             },
#             "firstYearOfPlay": "1993",
#             "franchise": {
#                 "franchiseId": 33,
#                 "link": "/api/v1/franchises/33",
#                 "teamName": "Panthers"
#             },
#             "franchiseId": 33,
#             "id": 13,
# ...

# %%
response = requests.get(url + "/14").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "TBL",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "A",
#                 "id": 17,
#                 "link": "/api/v1/divisions/17",
#                 "name": "Atlantic",
#                 "nameShort": "ATL"
#             },
#             "firstYearOfPlay": "1991",
#             "franchise": {
#                 "franchiseId": 31,
#                 "link": "/api/v1/franchises/31",
#                 "teamName": "Lightning"
#             },
#             "franchiseId": 31,
#             "id": 14,
# ...

# %%
response = requests.get(url + "/15").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "WSH",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1974",
#             "franchise": {
#                 "franchiseId": 24,
#                 "link": "/api/v1/franchises/24",
#                 "teamName": "Capitals"
#             },
#             "franchiseId": 24,
#             "id": 15,
# ...

# %%
response = requests.get(url + "/16").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "CHI",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "C",
#                 "id": 16,
#                 "link": "/api/v1/divisions/16",
#                 "name": "Central",
#                 "nameShort": "CEN"
#             },
#             "firstYearOfPlay": "1926",
#             "franchise": {
#                 "franchiseId": 11,
#                 "link": "/api/v1/franchises/11",
#                 "teamName": "Blackhawks"
#             },
#             "franchiseId": 11,
#             "id": 16,
# ...

# %%
response = requests.get(url + "/17").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "DET",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "A",
#                 "id": 17,
#                 "link": "/api/v1/divisions/17",
#                 "name": "Atlantic",
#                 "nameShort": "ATL"
#             },
#             "firstYearOfPlay": "1926",
#             "franchise": {
#                 "franchiseId": 12,
#                 "link": "/api/v1/franchises/12",
#                 "teamName": "Red Wings"
#             },
#             "franchiseId": 12,
#             "id": 17,
# ...

# %%
response = requests.get(url + "/18").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "NSH",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "C",
#                 "id": 16,
#                 "link": "/api/v1/divisions/16",
#                 "name": "Central",
#                 "nameShort": "CEN"
#             },
#             "firstYearOfPlay": "1997",
#             "franchise": {
#                 "franchiseId": 34,
#                 "link": "/api/v1/franchises/34",
#                 "teamName": "Predators"
#             },
#             "franchiseId": 34,
#             "id": 18,
# ...

# %%
response = requests.get(url + "/19").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "STL",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "C",
#                 "id": 16,
#                 "link": "/api/v1/divisions/16",
#                 "name": "Central",
#                 "nameShort": "CEN"
#             },
#             "firstYearOfPlay": "1967",
#             "franchise": {
#                 "franchiseId": 18,
#                 "link": "/api/v1/franchises/18",
#                 "teamName": "Blues"
#             },
#             "franchiseId": 18,
#             "id": 19,
# ...

# %%
response = requests.get(url + "/20").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "CGY",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "P",
#                 "id": 15,
#                 "link": "/api/v1/divisions/15",
#                 "name": "Pacific",
#                 "nameShort": "PAC"
#             },
#             "firstYearOfPlay": "1980",
#             "franchise": {
#                 "franchiseId": 21,
#                 "link": "/api/v1/franchises/21",
#                 "teamName": "Flames"
#             },
#             "franchiseId": 21,
#             "id": 20,
# ...

# %%
response = requests.get(url + "/21").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "COL",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "C",
#                 "id": 16,
#                 "link": "/api/v1/divisions/16",
#                 "name": "Central",
#                 "nameShort": "CEN"
#             },
#             "firstYearOfPlay": "1979",
#             "franchise": {
#                 "franchiseId": 27,
#                 "link": "/api/v1/franchises/27",
#                 "teamName": "Avalanche"
#             },
#             "franchiseId": 27,
#             "id": 21,
# ...

# %%
response = requests.get(url + "/22").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "EDM",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "P",
#                 "id": 15,
#                 "link": "/api/v1/divisions/15",
#                 "name": "Pacific",
#                 "nameShort": "PAC"
#             },
#             "firstYearOfPlay": "1979",
#             "franchise": {
#                 "franchiseId": 25,
#                 "link": "/api/v1/franchises/25",
#                 "teamName": "Oilers"
#             },
#             "franchiseId": 25,
#             "id": 22,
# ...

# %%
response = requests.get(url + "/23").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "VAN",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "P",
#                 "id": 15,
#                 "link": "/api/v1/divisions/15",
#                 "name": "Pacific",
#                 "nameShort": "PAC"
#             },
#             "firstYearOfPlay": "1970",
#             "franchise": {
#                 "franchiseId": 20,
#                 "link": "/api/v1/franchises/20",
#                 "teamName": "Canucks"
#             },
#             "franchiseId": 20,
#             "id": 23,
# ...

# %%
response = requests.get(url + "/24").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "ANA",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "P",
#                 "id": 15,
#                 "link": "/api/v1/divisions/15",
#                 "name": "Pacific",
#                 "nameShort": "PAC"
#             },
#             "firstYearOfPlay": "1993",
#             "franchise": {
#                 "franchiseId": 32,
#                 "link": "/api/v1/franchises/32",
#                 "teamName": "Ducks"
#             },
#             "franchiseId": 32,
#             "id": 24,
# ...

# %%
response = requests.get(url + "/25").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "DAL",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "C",
#                 "id": 16,
#                 "link": "/api/v1/divisions/16",
#                 "name": "Central",
#                 "nameShort": "CEN"
#             },
#             "firstYearOfPlay": "1967",
#             "franchise": {
#                 "franchiseId": 15,
#                 "link": "/api/v1/franchises/15",
#                 "teamName": "Stars"
#             },
#             "franchiseId": 15,
#             "id": 25,
# ...

# %%
response = requests.get(url + "/26").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "LAK",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "P",
#                 "id": 15,
#                 "link": "/api/v1/divisions/15",
#                 "name": "Pacific",
#                 "nameShort": "PAC"
#             },
#             "firstYearOfPlay": "1967",
#             "franchise": {
#                 "franchiseId": 14,
#                 "link": "/api/v1/franchises/14",
#                 "teamName": "Kings"
#             },
#             "franchiseId": 14,
#             "id": 26,
# ...

# %%
response = requests.get(url + "/27").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "PHX",
#             "active": false,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "P",
#                 "id": 15,
#                 "link": "/api/v1/divisions/15",
#                 "name": "Pacific",
#                 "nameShort": "PAC"
#             },
#             "firstYearOfPlay": "1979",
#             "franchise": {
#                 "franchiseId": 28,
#                 "link": "/api/v1/franchises/28",
#                 "teamName": "Coyotes"
#             },
#             "franchiseId": 28,
#             "id": 27,
# ...

# %%
response = requests.get(url + "/28").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "SJS",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "P",
#                 "id": 15,
#                 "link": "/api/v1/divisions/15",
#                 "name": "Pacific",
#                 "nameShort": "PAC"
#             },
#             "firstYearOfPlay": "1990",
#             "franchise": {
#                 "franchiseId": 29,
#                 "link": "/api/v1/franchises/29",
#                 "teamName": "Sharks"
#             },
#             "franchiseId": 29,
#             "id": 28,
# ...

# %%
response = requests.get(url + "/29").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "CBJ",
#             "active": true,
#             "conference": {
#                 "id": 6,
#                 "link": "/api/v1/conferences/6",
#                 "name": "Eastern"
#             },
#             "division": {
#                 "abbreviation": "M",
#                 "id": 18,
#                 "link": "/api/v1/divisions/18",
#                 "name": "Metropolitan",
#                 "nameShort": "Metro"
#             },
#             "firstYearOfPlay": "1997",
#             "franchise": {
#                 "franchiseId": 36,
#                 "link": "/api/v1/franchises/36",
#                 "teamName": "Blue Jackets"
#             },
#             "franchiseId": 36,
#             "id": 29,
# ...

# %%
response = requests.get(url + "/30").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "MIN",
#             "active": true,
#             "conference": {
#                 "id": 5,
#                 "link": "/api/v1/conferences/5",
#                 "name": "Western"
#             },
#             "division": {
#                 "abbreviation": "C",
#                 "id": 16,
#                 "link": "/api/v1/divisions/16",
#                 "name": "Central",
#                 "nameShort": "CEN"
#             },
#             "firstYearOfPlay": "1997",
#             "franchise": {
#                 "franchiseId": 37,
#                 "link": "/api/v1/franchises/37",
#                 "teamName": "Wild"
#             },
#             "franchiseId": 37,
#             "id": 30,
# ...

# %%
response = requests.get(url + "/31").json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "copyright": "NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. \u00a9 NHL 2020. All Rights Reserved.",
#     "teams": [
#         {
#             "abbreviation": "MNS",
#             "active": false,
#             "conference": {
#                 "id": 3,
#                 "link": "/api/v1/conferences/3",
#                 "name": "Prince of Wales"
#             },
#             "division": {
#                 "id": 12,
#                 "link": "/api/v1/divisions/12",
#                 "name": "Norris"
#             },
#             "franchise": {
#                 "franchiseId": 15,
#                 "link": "/api/v1/franchises/15",
#                 "teamName": "Stars"
#             },
#             "franchiseId": 15,
#             "id": 31,
#             "link": "/api/v1/teams/31",
#             "locationName": "Minnesota",
#             "name": "Minnesota North Stars",
# ...
